# %%
import matplotlib.pyplot as plt

# %%
batch_loss = [34.6159850358963, 18.184853728000935, 14.599916004217588, 12.889524757862091, 11.8831897515517, 11.440785018297342, 10.803193743412312, 10.648080055530254, 9.696078341740828, 9.980157279051268, 8.656373225725615, 8.919910556994951, 8.4219229221344, 8.877171167960533, 8.455109286766787, 8.004852281166958, 8.395885563813723, 8.115127322765497, 8.050941950999773, 7.534582216006059, 7.912463788802807, 8.085439638449596, 7.680561391206888, 7.571489916397975, 7.924892207750907, 7.559530608929121, 7.187822755712729, 6.511740189332229, 7.3367307507074795, 7.145955191208766, 6.714314362177482, 7.108838523809727, 6.7520399529200334, 7.0248270103564625, 7.154828305427845, 6.956658571958542, 6.739393988480935]

# %%
dev_fscore = [62.6, 70.71, 74.44, 77.02, 79.29, 80.89, 81.4, 81.36, 82.04, 82.78, 83.84, 84.27, 84.21, 85.26, 85.13, 85.03, 85.68, 85.74, 85.83, 86.02, 85.82, 86.32, 86.28, 86.51, 86.61, 86.42, 86.55, 87.09, 86.78, 86.78, 87.02, 87.17, 86.85, 87.25, 87.53, 87.76, 87.77]

# %%
processed = [var for var in range(1,38)]

# %%
fig, ax = plt.subplots()
ax.plot(processed, batch_loss, 'r--', label="Batch Loss")
ax.plot(processed, dev_fscore, 'g--', label="F1score")
plt.xlabel("Number of trees processed in 1000s")
plt.ylabel("Percentage")

legend = ax.legend(loc='center right', shadow=True, fontsize='x-large')


plt.show()
